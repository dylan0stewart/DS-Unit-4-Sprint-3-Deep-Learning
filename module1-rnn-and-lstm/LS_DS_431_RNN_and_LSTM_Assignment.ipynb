# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
# Imports
import numpy as np
import random
import sys
import urllib.request

from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
# Read in data
full_text = []
url = "https://www.gutenberg.org/files/100/100-0.txt"
for line in urllib.request.urlopen(url):
    full_text.append(line.decode('utf-8'))

# %%
# Strip lines from remaining HTML characters
cleaned_full_text = []
for line in full_text[139:-430]:
    cleaned_full_text.append(line.strip())

# %%
# Create titles data
titles = []
for line in full_text[44:129:2]:
    titles.append(line.strip())

# %%
# Separate out sonnets 
sonnets = []
for line in cleaned_full_text[:2767]:
  sonnets.append(line)

# %%
# Use titles list to create first draft of model

# Gather all text
text = " ".join(titles)

# Create unique character list
chars = list(set(text))

# Create character lookup tables
char_int = {c:i for i, c in enumerate(chars)}
int_char = {i:c for i, c in enumerate(chars)}

len(chars)
# Out:
# 28

# %%
# Use titles list to create first draft of model

# Gather all text
text = " ".join(titles)

# Create unique character list
chars = list(set(text))

# Create character lookup tables
char_int = {c:i for i, c in enumerate(chars)}
int_char = {i:c for i, c in enumerate(chars)}

len(chars)
# Out:
# 28

# %%
# find average character length of titles
lengths = []
sum_num = 0
for title in titles:
  lengths.append(len(title))
for length in lengths:
  sum_num += length
sum_num / len(lengths)
# Out:
# 25.372093023255815

# %%
# Create sequence data 
maxlen = 25
step = 5

# Create encoded data
encoded = [char_int[c] for c in text]

# Create empty sequence & next character lists
sequences = []
next_char = []

# fill empty lists
for i in range(0, len(encoded) - maxlen, step):
  sequences.append(encoded[i : i + maxlen])
  next_char.append(encoded[i + maxlen])

print('Sequence Qty: ', len(sequences))
# Out:
# Sequence Qty:  222

# %%
# One hot encode data to prepare for model
x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
  for t, char in enumerate(sequence):
    x[i, t, char] = 1
  y[i, next_char[i]] = 1

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               80384
# _________________________________________________________________
# dense (Dense)                (None, 28)                3612
# =================================================================
# Total params: 83,996
# Trainable params: 83,996
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create functions to make use of model outputs
def indexer(preds):
  # Helper function to take highest probability & pull given index
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / 1
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

def on_epoch_end(epoch, _):
  # Function to generate predicted text at each epoch
  print()
  print('---- Generating text after Epoch: %d' % epoch)

  start_index = random.randint(0, len(text) - maxlen - 1)

  generated = ''

  sentence = text[start_index: start_index + maxlen]

  generated += sentence

  print('---- Generating with seed: "' + sentence + '"')
  # sys.stdout.write(generated)

  for i in range(25):
    x_pred = np.zeros((1, maxlen, len(chars)))
    for t, char in enumerate(sentence):
      x_pred[0, t, char_int[char]] = 1

    preds = model.predict(x_pred, verbose=0)[0]
    next_index = indexer(preds)
    next_char = int_char[next_index]

    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
  print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
# fit the model
model.fit(x, y,
          batch_size=32,
          epochs=100,
          callbacks=[print_callback])
# Out:
# Train on 222 samples
# Epoch 1/100
# 160/222 [====================>.........] - ETA: 0s - loss: 3.3198
# ---- Generating text after Epoch: 0
# ---- Generating with seed: "OMEO AND JULIET THE TAMIN"
# VDDFFLCUETYNKE;JDLXJDH,KD
# 222/222 [==============================] - 3s 12ms/sample - loss: 3.3087
# Epoch 2/100
# 160/222 [====================>.........] - ETA: 0s - loss: 3.2064
# ---- Generating text after Epoch: 1
# ---- Generating with seed: "MEDY OF ERRORS THE TRAGED"
# RTOEEOEOX PTDFN ; ;OHLONE
# 222/222 [==============================] - 1s 4ms/sample - loss: 3.1492
# Epoch 3/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.9527
# ---- Generating text after Epoch: 2
# ---- Generating with seed: "IRST PART OF KING HENRY T"
#  DHSOOEREOKHH NNGHHDROIEE
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.9540
# Epoch 4/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7777
# ---- Generating text after Epoch: 3
# ---- Generating with seed: "N OF ATHENS THE TRAGEDY O"
# F PNEO HNNIE OU PT F FTHO
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.8597
# Epoch 5/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8302
# ---- Generating text after Epoch: 4
# ---- Generating with seed: "F CORIOLANUS CYMBELINE TH"
# MGOIH TIOITRTGWKH OEHWTYU
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.8418
# Epoch 6/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8497
# ---- Generating text after Epoch: 5
# ---- Generating with seed: "LL THAT ENDS WELL THE TRA"
# EOE T H EO GEIRUAHRUHEAIO
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.8238
# Epoch 7/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8096
# ---- Generating text after Epoch: 6
# ---- Generating with seed: "ETH MEASURE FOR MEASURE T"
# SFRSGTFHI AH  NHSHFEMPIEH
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.8069
# Epoch 8/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7909
# ---- Generating text after Epoch: 7
# ---- Generating with seed: "HE HISTORY OF TROILUS AND"
#  ANRDSTSOIEHXNJDITTRADTGE
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.7987
# Epoch 9/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.7985
# ---- Generating text after Epoch: 8
# ---- Generating with seed: "LL’S WELL THAT ENDS WELL "
#  TSENDAI  IRU,OFAFGRTOTAF
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7876
# Epoch 10/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7600
# ---- Generating text after Epoch: 9
# ---- Generating with seed: "HE FOURTH THE SECOND PART"
# NC  AITAR A FHOEHFPONYTOT
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.7686
# Epoch 11/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.7787
# ---- Generating text after Epoch: 10
# ---- Generating with seed: "G HENRY THE EIGHTH KING J"
#  A DHIMSEIOGH  TLEELTDUN
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.7528
# Epoch 12/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.7675
# ---- Generating text after Epoch: 11
# ---- Generating with seed: "COND KING RICHARD THE THI"
# YPGTHES TOYRTP OIHHLEGE U
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7379
# Epoch 13/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.6947
# ---- Generating text after Epoch: 12
# ---- Generating with seed: "F LUCRECE VENUS AND ADONI"
# FIOO R PHLANA DRTIS ERYD
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7333
# Epoch 14/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.7441
# ---- Generating text after Epoch: 13
# ---- Generating with seed: "LL THE TWO GENTLEMEN OF V"
# CCUOANERYTMETG NNATN OHIG
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.7175
# Epoch 15/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.5917
# ---- Generating text after Epoch: 14
# ---- Generating with seed: "ULIET THE TAMING OF THE S"
# MF AERYY HENSOHTOUEHEERRG
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.6958
# Epoch 16/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.6358
# ---- Generating text after Epoch: 15
# ---- Generating with seed: "EDY OF ANTONY AND CLEOPAT"
# HYENRUOIDENTA PPYTNERRSN
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.6526
# Epoch 17/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.6113
# ---- Generating text after Epoch: 16
# ---- Generating with seed: "NRY THE FOURTH THE SECOND"
# EIEM,IIO  INDI NDNF HHV’’
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.6183
# Epoch 18/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.5867
# ---- Generating text after Epoch: 17
# ---- Generating with seed: "US AND CRESSIDA TWELFTH N"
# VRAEE WOEAHET I FH TGE ID
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.5830
# Epoch 19/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.4532
# ---- Generating text after Epoch: 18
# ---- Generating with seed: " EIGHTH KING JOHN THE TRA"
#  SNGEPEG II NDTDUE  DEGHO
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.5481
# Epoch 20/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.4954
# ---- Generating text after Epoch: 19
# ---- Generating with seed: "NOTHING THE TRAGEDY OF OT"
# NPATM HEN VHTPERUVREGTIDP
# 222/222 [==============================] - 1s 6ms/sample - loss: 2.5149
# Epoch 21/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.4687
# ---- Generating text after Epoch: 20
# ---- Generating with seed: "OF TROILUS AND CRESSIDA T"
# LIAHNOEHFT NHGONRY SETILN
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.4990
# Epoch 22/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.5122
# ---- Generating text after Epoch: 21
# ---- Generating with seed: "PERICLES, PRINCE OF TYRE "
# IUORHS DIAEEHFITTIGEOFUNS
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.4514
# Epoch 23/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.4071
# ---- Generating text after Epoch: 22
# ---- Generating with seed: "BETH MEASURE FOR MEASURE "
# ITEV UNTOGNOT EAOEN TH ED
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.4029
# Epoch 24/100
# 128/222 [================>.............] - ETA: 0s - loss: 2.4481
# ---- Generating text after Epoch: 23
# ---- Generating with seed: "OPATRA AS YOU LIKE IT THE"
# N L TRDDEU FT WIAIRAT ESI
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.3590
# Epoch 25/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.3069
# ---- Generating text after Epoch: 24
# ---- Generating with seed: "KING HENRY THE SIXTH THE "
# OWO OT RE TE DAD IN OTI T
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.3322
# Epoch 26/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.2536
# ---- Generating text after Epoch: 25
# ---- Generating with seed: "M MUCH ADO ABOUT NOTHING "
# OMYNDRD OA RIA, MUOOGRIYY
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.2634
# Epoch 27/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.2887
# ---- Generating text after Epoch: 26
# ---- Generating with seed: "COMEDY OF ERRORS THE TRAG"
# FE OO EMEUNETUF,PHONVE TH
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.2141
# Epoch 28/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.2128
# ---- Generating text after Epoch: 27
# ---- Generating with seed: "THE TRAGEDY OF JULIUS CAE"
# DHYSOTDE TI ROCEPNUTEMEET
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.2411
# Epoch 29/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.1766
# ---- Generating text after Epoch: 28
# ---- Generating with seed: "HE PASSIONATE PILGRIM THE"
# DTARBECBHE  AOLTH,T T RIH
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.1878
# Epoch 30/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.1440
# ---- Generating text after Epoch: 29
# ---- Generating with seed: " TWELFTH NIGHT; OR, WHAT "
# EDRYOR ODTRU RRYEED  EIUR
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.1209
# Epoch 31/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.0041
# ---- Generating text after Epoch: 30
# ---- Generating with seed: "THE EIGHTH KING JOHN THE "
# ATTHGPFEE TAO RNRAPDEHYD
# 222/222 [==============================] - 1s 4ms/sample - loss: 2.0363
# Epoch 32/100
# 192/222 [========================>.....] - ETA: 0s - loss: 1.9516
# ---- Generating text after Epoch: 31
# ---- Generating with seed: "OTHING THE TRAGEDY OF OTH"
# NORRAPDGOED YTT IIMSDTHNH
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.9635
# Epoch 33/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.9111
# ---- Generating text after Epoch: 32
# ---- Generating with seed: "ROILUS AND CRESSIDA TWELF"
# IGEAYITRO TS;,MEGVASBDKV;
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.9146
# Epoch 34/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.8112
# ---- Generating text after Epoch: 33
# ---- Generating with seed: "LOST THE TRAGEDY OF MACBE"
# EAMDPNHLT HVENHTHTHEAOEUY
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.8481
# Epoch 35/100
# 128/222 [================>.............] - ETA: 0s - loss: 1.7709
# ---- Generating text after Epoch: 34
# ---- Generating with seed: "XTH KING HENRY THE EIGHTH"
# EN A RFAAUUS OONA UNTYY T
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.7945
# Epoch 36/100
# 192/222 [========================>.....] - ETA: 0s - loss: 1.7589
# ---- Generating text after Epoch: 35
# ---- Generating with seed: "F OTHELLO, MOOR OF VENICE"
# N FD AINTV,EFHREESDT,,LPP
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.7546
# Epoch 37/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.7406
# ---- Generating text after Epoch: 36
# ---- Generating with seed: "WO NOBLE KINSMEN THE WINT"
# AR V GKOIU ’YRTED HTHELM
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.8272
# Epoch 38/100
# 128/222 [================>.............] - ETA: 0s - loss: 1.7598
# ---- Generating text after Epoch: 37
# ---- Generating with seed: "F TROILUS AND CRESSIDA TW"
# EDTIDWNI IIRTRRMJWAESTTC,
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.7311
# Epoch 39/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.6056
# ---- Generating text after Epoch: 38
# ---- Generating with seed: "F THE SHREW THE TEMPEST T"
# E I WHORIFW AT  IHETEI IT
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.6353
# Epoch 40/100
# 192/222 [========================>.....] - ETA: 0s - loss: 1.5390
# ---- Generating text after Epoch: 39
# ---- Generating with seed: "XTH THE THIRD PART OF KIN"
#   RAFGIIDE D O UED Y OUII
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.6279
# Epoch 41/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.6295
# ---- Generating text after Epoch: 40
# ---- Generating with seed: "LFTH NIGHT; OR, WHAT YOU "
# IIIONTEIT TOMITOTHMIDPVRF
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.5944
# Epoch 42/100
# 192/222 [========================>.....] - ETA: 0s - loss: 1.4783
# ---- Generating text after Epoch: 41
# ---- Generating with seed: "THE LIFE OF TIMON OF ATHE"
# ONRAV ENDSUIL TITHSHEFMWS
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.4962
# Epoch 43/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.3860
# ---- Generating text after Epoch: 42
# ---- Generating with seed: "MLET, PRINCE OF DENMARK T"
# MYAH YIDFOIRHHE TPCEPHEGG
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.4264
# Epoch 44/100
# 128/222 [================>.............] - ETA: 0s - loss: 1.3581
# ---- Generating text after Epoch: 43
# ---- Generating with seed: "UR’S LOST THE TRAGEDY OF "
#  HTTT MM,DEDTF FN ATME RE
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.3646
# Epoch 45/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.3606
# ---- Generating text after Epoch: 44
# ---- Generating with seed: " THE TRAGEDY OF OTHELLO, "
# DLNNTONNA THTLPARGEFYWHNI
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.3358
# Epoch 46/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.2291
# ---- Generating text after Epoch: 45
# ---- Generating with seed: "ICE THE MERRY WIVES OF WI"
# IINNMRY AORT TJEOIN TNIUO
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.2201
# Epoch 47/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.1214
# ---- Generating text after Epoch: 46
# ---- Generating with seed: "YOU WILL THE TWO GENTLEME"
# NNNT,CLNHAARAGSOEOKN’EVVJ
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.1444
# Epoch 48/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.0605
# ---- Generating text after Epoch: 47
# ---- Generating with seed: "THE WINTER’S TALE A LOVER"
# THADF,O OOUT, TINRYIGIRIT
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.0810
# Epoch 49/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.9214
# ---- Generating text after Epoch: 48
# ---- Generating with seed: " AND THE TURTLE THE RAPE "
# ETEE  F GINNIIERHSM HEEEE
# 222/222 [==============================] - 1s 4ms/sample - loss: 1.0268
# Epoch 50/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.9338
# ---- Generating text after Epoch: 49
# ---- Generating with seed: "ERICLES, PRINCE OF TYRE K"
# SPPE HII EYDT ODOO RNRADR
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.9652
# Epoch 51/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.9553
# ---- Generating text after Epoch: 50
# ---- Generating with seed: "TAMING OF THE SHREW THE T"
#  E DOO TFNITUIMEDRE IITRH
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.9394
# Epoch 52/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.9269
# ---- Generating text after Epoch: 51
# ---- Generating with seed: "ANT OF VENICE THE MERRY W"
#  OIO T RTIGTGEIG TOO T ON
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.9351
# Epoch 53/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.8305
# ---- Generating text after Epoch: 52
# ---- Generating with seed: " THE SECOND PART OF KING "
# TRTT ITTT  T DN  NIN ARIR
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.8490
# Epoch 54/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.8310
# ---- Generating text after Epoch: 53
# ---- Generating with seed: "IET THE TAMING OF THE SHR"
# EEDYEEPGPWTEONFNPIEA ,WJW
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.8362
# Epoch 55/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.7273
# ---- Generating text after Epoch: 54
# ---- Generating with seed: "NE THE TRAGEDY OF HAMLET,"
# MMMAPSOOOFLF NO F VAC YFD
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.7433
# Epoch 56/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.7564
# ---- Generating text after Epoch: 55
# ---- Generating with seed: "CLEOPATRA AS YOU LIKE IT "
# EOTOH TT OIIDG TRTE REDUR
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.7461
# Epoch 57/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.7223
# ---- Generating text after Epoch: 56
# ---- Generating with seed: " OF DENMARK THE FIRST PAR"
# PDO OORNTUNTNIYEHIT NTTOH
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.7114
# Epoch 58/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.7091
# ---- Generating text after Epoch: 57
# ---- Generating with seed: "HE COMEDY OF ERRORS THE T"
# EPPGGGO ONORUHNIORYYL,LTF
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.7165
# Epoch 59/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.6977
# ---- Generating text after Epoch: 58
# ---- Generating with seed: "GHTH KING JOHN THE TRAGED"
#     ONLTE  RDDDD   T TE
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.6792
# Epoch 60/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.5621
# ---- Generating text after Epoch: 59
# ---- Generating with seed: " OF VERONA THE TWO NOBLE "
#  T OHHMMMHNSMROOO FF   TH
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.5770
# Epoch 61/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.5809
# ---- Generating text after Epoch: 60
# ---- Generating with seed: "SIONATE PILGRIM THE PHOEN"
# VRFFRE EO MTHERHHINMIJJOO
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.5837
# Epoch 62/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.5273
# ---- Generating text after Epoch: 61
# ---- Generating with seed: "IONATE PILGRIM THE PHOENI"
# T  OAOF,YNNMNNTRRD OIXRHL
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.5289
# Epoch 63/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.4689
# ---- Generating text after Epoch: 62
# ---- Generating with seed: " KING RICHARD THE THIRD T"
#  OOTE U E EITTDD DED   O
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.5046
# Epoch 64/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.5149
# ---- Generating text after Epoch: 63
# ---- Generating with seed: "S TALE A LOVER’S COMPLAIN"
# UTTO    NINIRDNDU   ,ITII
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.5109
# Epoch 65/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.5338
# ---- Generating text after Epoch: 64
# ---- Generating with seed: "RD THE SECOND KING RICHAR"
# EUEDE  TOPIT TIIIDGDNDWRO
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.5001
# Epoch 66/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4171
# ---- Generating text after Epoch: 65
# ---- Generating with seed: ", WHAT YOU WILL THE TWO G"
# DTTDT  NMNYR TRTTDE EEEUF
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.4318
# Epoch 67/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.3800
# ---- Generating text after Epoch: 66
# ---- Generating with seed: "G THE TRAGEDY OF OTHELLO,"
# NM,OHIOMOOVNNNP’LGAGWC;H
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3838
# Epoch 68/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.3506
# ---- Generating text after Epoch: 67
# ---- Generating with seed: "LE THE RAPE OF LUCRECE VE"
# UUDUDDR  OIR ATEADDIDIEII
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3441
# Epoch 69/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2928
# ---- Generating text after Epoch: 68
# ---- Generating with seed: "S TALE A LOVER’S COMPLAIN"
# TTOO    NIINNMNDEPFTYN LL
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3100
# Epoch 70/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2703
# ---- Generating text after Epoch: 69
# ---- Generating with seed: "ING LEAR LOVE’S LABOUR’S "
# OOONAAHA  HHUSDTTI ET TU
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.2771
# Epoch 71/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2544
# ---- Generating text after Epoch: 70
# ---- Generating with seed: "T PART OF KING HENRY THE "
# OOUTH  TUITEED  T T  FUMU
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.2560
# Epoch 72/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2055
# ---- Generating text after Epoch: 71
# ---- Generating with seed: "A MIDSUMMER NIGHT’S DREAM"
#  ODJOS OAINNMIDDDSTDPPETT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2335
# Epoch 73/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2089
# ---- Generating text after Epoch: 72
# ---- Generating with seed: "NRY THE SIXTH KING HENRY "
# UAEAOOO L TH NPLIIMDI TN
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.2179
# Epoch 74/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1568
# ---- Generating text after Epoch: 73
# ---- Generating with seed: "ECOND PART OF KING HENRY "
# TTE TOUTM    NNRRRNEEE  D
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.2031
# Epoch 75/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.2030
# ---- Generating text after Epoch: 74
# ---- Generating with seed: "OF HAMLET, PRINCE OF DENM"
# TTTTENEEIIOFFF RETEEOSFNY
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1913
# Epoch 76/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.1755
# ---- Generating text after Epoch: 75
# ---- Generating with seed: "ING RICHARD THE SECOND KI"
# IIINIITTEDEYHTIOLME;VSX,T
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1931
# Epoch 77/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.2049
# ---- Generating text after Epoch: 76
# ---- Generating with seed: "AGEDY OF ANTONY AND CLEOP"
# FLVAADYYYYIVIIITHAA,N,,LY
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.2011
# Epoch 78/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1904
# ---- Generating text after Epoch: 77
# ---- Generating with seed: "Y OF JULIUS CAESAR THE TR"
# PGGGGOORNURRTAHAEAYLOOOUU
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1956
# Epoch 79/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1524
# ---- Generating text after Epoch: 78
# ---- Generating with seed: " HAMLET, PRINCE OF DENMAR"
# GETNIIIITHHESSTEESPXJKJ’S
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1858
# Epoch 80/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.1799
# ---- Generating text after Epoch: 79
# ---- Generating with seed: "ING HENRY THE FOURTH THE "
# LEGUDO    TTRTN NNU DN OO
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1889
# Epoch 81/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1689
# ---- Generating text after Epoch: 80
# ---- Generating with seed: "WO GENTLEMEN OF VERONA TH"
# N  WNNNNNT  T  THHHTTHYPY
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1676
# Epoch 82/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1483
# ---- Generating text after Epoch: 81
# ---- Generating with seed: "NTONY AND CLEOPATRA AS YO"
# IIIIIIHETTTET TTHTTO XCY,
# 222/222 [==============================] - 1s 6ms/sample - loss: 0.1670
# Epoch 83/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1533
# ---- Generating text after Epoch: 82
# ---- Generating with seed: "OUT NOTHING THE TRAGEDY O"
#     ALLELMMN,MNDNN OO H N
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2056
# Epoch 84/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.3129
# ---- Generating text after Epoch: 83
# ---- Generating with seed: "OF ERRORS THE TRAGEDY OF "
# TTRHE NDDDYYIIO OATA EIYN
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3242
# Epoch 85/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.5174
# ---- Generating text after Epoch: 84
# ---- Generating with seed: "MER NIGHT’S DREAM MUCH AD"
# O A ULUE UT T TUGD   T U
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.5406
# Epoch 86/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4615
# ---- Generating text after Epoch: 85
# ---- Generating with seed: " THE WINTER’S TALE A LOVE"
# NSSTHWDIPWIM DPOR  HIYRJI
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4386
# Epoch 87/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.4174
# ---- Generating text after Epoch: 86
# ---- Generating with seed: "T’S DREAM MUCH ADO ABOUT "
# EUTEEEGF  TDTHHSNRORERRE
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3862
# Epoch 88/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.2468
# ---- Generating text after Epoch: 87
# ---- Generating with seed: "WIVES OF WINDSOR A MIDSUM"
# MIIITIIT HHHHA AO YSLEHYO
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2902
# Epoch 89/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.2594
# ---- Generating text after Epoch: 88
# ---- Generating with seed: "HE TRAGEDY OF HAMLET, PRI"
# NOT NFF NNTETTTTNRESWDF
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2801
# Epoch 90/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.2518
# ---- Generating text after Epoch: 89
# ---- Generating with seed: "ND THE TURTLE THE RAPE OF"
# EEDLUEETEET,HDNNOIOFOFAAA
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2591
# Epoch 91/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.1880
# ---- Generating text after Epoch: 90
# ---- Generating with seed: "EDY OF MACBETH MEASURE FO"
# F EEEEEUTUAHHI RTO  ORTFR
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1904
# Epoch 92/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.1754
# ---- Generating text after Epoch: 91
# ---- Generating with seed: "HE TWO GENTLEMEN OF VERON"
# AAAVR  NNNYNTTH  TT HHTHH
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1692
# Epoch 93/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.1441
# ---- Generating text after Epoch: 92
# ---- Generating with seed: " WHAT YOU WILL THE TWO GE"
# DTT NN MMTUT,IOONMHENTTYT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1335
# Epoch 94/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1082
# ---- Generating text after Epoch: 93
# ---- Generating with seed: " COMEDY OF ERRORS THE TRA"
# GGGGOOOTTROHHOHANDOLYOGME
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.1163
# Epoch 95/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.0978
# ---- Generating text after Epoch: 94
# ---- Generating with seed: "THE FIFTH THE FIRST PART "
# FFFF TNNRERRRRTAUUUUUEGGE
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.0998
# Epoch 96/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.1035
# ---- Generating text after Epoch: 95
# ---- Generating with seed: "OTHELLO, MOOR OF VENICE P"
# OFLNLEIMMPIIMHEHPSASFFSXP
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.0896
# Epoch 97/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.0741
# ---- Generating text after Epoch: 96
# ---- Generating with seed: " WINTER’S TALE A LOVER’S "
# HBSPPTTTTTOO     FNNNUNDE
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0819
# Epoch 98/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.0849
# ---- Generating text after Epoch: 97
# ---- Generating with seed: "ST PART OF KING HENRY THE"
# U OUTH  HE MLEE DUD   HSA
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.0770
# Epoch 99/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.0785
# ---- Generating text after Epoch: 98
# ---- Generating with seed: "G OF THE SHREW THE TEMPES"
#  TTNEIIIIIIFFFT EAOCFOORL
# 222/222 [==============================] - 1s 4ms/sample - loss: 0.0720
# Epoch 100/100
# 128/222 [================>.............] - ETA: 0s - loss: 0.0755
# ---- Generating text after Epoch: 99
# ---- Generating with seed: "EN THE WINTER’S TALE A LO"
# OTTSSHTOPSINI TWOORRRST’L
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0681

# %%
# Try with sonnets

# Gather all text
text = " ".join(sonnets)

# Create unique character list
chars = list(set(text))

# Create character lookup tables
char_int = {c:i for i, c in enumerate(chars)}
int_char = {i:c for i, c in enumerate(chars)}

len(chars)
# Out:
# 71

# %%
# Create sequence data 
maxlen = 40
step = 5

# Create encoded data
encoded = [char_int[c] for c in text]

# Create empty sequence & next character lists
sequences = []
next_char = []

# fill empty lists
for i in range(0, len(encoded) - maxlen, step):
  sequences.append(encoded[i : i + maxlen])
  next_char.append(encoded[i + maxlen])

print('Sequence Qty: ', len(sequences))
# Out:
# Sequence Qty:  18918

# %%
# One hot encode data to prepare for model
x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
  for t, char in enumerate(sequence):
    x[i, t, char] = 1
  y[i, next_char[i]] = 1

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               102400
# _________________________________________________________________
# dense_1 (Dense)              (None, 71)                9159
# =================================================================
# Total params: 111,559
# Trainable params: 111,559
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create functions to make use of model outputs
def indexer(preds):
  # Helper function to take highest probability & pull given index
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / 1
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

def on_epoch_end(epoch, _):
  # Function to generate predicted text at each epoch
  print()
  print('---- Generating text after Epoch: %d' % epoch)

  start_index = random.randint(0, len(text) - maxlen - 1)

  generated = ''

  sentence = text[start_index: start_index + maxlen]

  generated += sentence

  print('---- Generating with seed: "' + sentence + '"')
  sys.stdout.write("\n")
  
  print('                 %d' % epoch)
  sys.stdout.write(generated)
  sys.stdout.write("\n")

  for i in range(13):
    for i in range(maxlen):   
      x_pred = np.zeros((1, maxlen, len(chars)))
      for t, char in enumerate(sentence):
        x_pred[0, t, char_int[char]] = 1

      preds = model.predict(x_pred, verbose=0)[0]
      next_index = indexer(preds)
      next_char = int_char[next_index]

      sentence = sentence[1:] + next_char

      sys.stdout.write(next_char)
      sys.stdout.flush()
    sys.stdout.write("\n")
  print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
# Fit model
model.fit(x, y,
          batch_size=32,
          epochs=100,
          callbacks=[print_callback])
# Out:
# Train on 18918 samples
# Epoch 1/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.9596
# ---- Generating text after Epoch: 0
# ---- Generating with seed: "the sweet smell Of different flowers in "
#
#                  0
# the sweet smell Of different flowers in
# kyoe tonovet sa nut lhu nh non e a de t
# veFc Iooeashf  wia  sI homet rhn newr yk
# rtjNe lglkoe, Bthtpruu ot, mead roms soc
#  n s sit gt,sat u.v  h oyn borh thet sin
#  nthosar  on ne  oceiklond tieo fe itkrt
#  bet gr hf ooy me th nh :t Ta a t, eand
# sorr oo  phe  ot  u d, ,v utk to  no e,
# 9ledr, ahhudkced tht thc ahrohevt,wcu re
#  th  sath uorin   ioetmet  h w tae rha o
# osrin tHes muoa, thet murs to o rsere wy
#   om tiiathumesiss pfS fe, yDtsfu ghy sh
# ito ,hend ponyi n: aov ler   g heehs ote
# r sthne agt2sSrf f.  itmlsdi aYh shn b.,
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 2.9592
# Epoch 2/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.5139
# ---- Generating text after Epoch: 1
# ---- Generating with seed: "do allow, For beauty’s pattern to succee"
#
#                  1
# do allow, For beauty’s pattern to succee
#  nhef feTum) I whoerf tehe, mr rhof wan
# thoriwd Anat whrurin A daus aFthethth sh
# oToangp 0he brien F’y Ortthael te fin eo
# up’seg. The Whece w tty ons’tf, Or antig
# sdw on mr hecdk fore, Thed,,  gn eo bugg
# , haet thir , woi vasretby peal  irn fnr
# t Mithe, As thve ind shawote t oe whovit
# e be ke slotng, :gk t-ther arenh f2qw in
# eigow warye, madw th feed thocey car cof
# tt eo coseet Be M ?as whsu dofu beas ede
#  eale tham eo thuy, Bf thw lonl pind shv
# e ool Wof  inin Ongr sirtois aiws mco I
# y obth r theusth pamen’ er ’ft ve d fmt
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 2.5139
# Epoch 3/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.3352
# ---- Generating text after Epoch: 2
# ---- Generating with seed: " fair acceptance shine? The sea all wate"
#
#                  2
#  fair acceptance shine? The sea all wate
#  bandwoisth7k I that yule silse I Ii3r n
# o) woth my yod thot dWimy thacht fatho h
# y mye? pundrcatrse, Be thece be: mr whem
# ac’Be, Andit, I che? mangith, An kouth h
# e Bt whive Theckwirgp palel dous Fpothev
#  ay ono chat thove beke Pidg ohe: inl8e
# thuth d dr aath seern hivwsod thamtss fo
# : inat . ghae midh ow?’be’ mecwomeon fan
#  and thceok Mproun hFetgcueslotigh whaw,
#  ming ued, bind louklor whe5 nut, ng icw
# e chirs I on lflma8t, ond nos lin oncopa
# st daot, an, ’ine, Sot whet but ot venbw
# pepsaar ypeqhan s kare thel  sade gheuos
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 2.3351
# Epoch 4/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.2345
# ---- Generating text after Epoch: 3
# ---- Generating with seed: " constant stars in them I read such art "
#
#                  3
#  constant stars in them I read such art
# pilendmeinos ind Ar ind posciroue doawkr
# s vin not balet of prapralt me if aedalt
# , ar fouches thous pom semethayt thti gh
# or noneawht, theeooid midhe ink -in erow
# ling mlits, toss thelec’ster noss om as-
# is fomd selish ptpy alemo fowlinter’anth
# e, Fo toar hanith ertrit l thas waren wi
# me, Bul it lor have, Kedendd silr, Thebe
# id chamenpeave. Or wame he’s that? mripp
# in woredh ay f ouns druk byesszereld, O
# -ovlkye: And Whacer th incomesen ale eic
# h cn pusR try bee vo’s ilurc theerI i1
# th’ ding bes alin fot whes so fofting pa
#
# 18918/18918 [==============================] - 35s 2ms/sample - loss: 2.2346
# Epoch 5/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 2.1606
# ---- Generating text after Epoch: 4
# ---- Generating with seed: "or trial needs would touch my breast, I "
#
#                  4
# or trial needs would touch my breast, I
# Thei ninge aosr, wimt ind Andascy sitht,
#  surt thes soughe ay os minotit muee.  n
# o kyames hinee meghith rotisgor pawven’
# lovered hes iBd huld, is thoull by mile
# some vill bale, I won seperin, And, O tl
# y amy warn than for-thy preig, Sh whse i
# o hen my when ind.  O1   194 Rin inN mst
#  ild cour ow my aliighe stinive thou pon
# girs oujeneq row ?ok palloun sor cilghe
# wo ark frmee, Tha thoussnI alghel nouted
# elis powpend cifde bin Whise, ond my lit
# huw, I dnet mot lis cer iilcstire mlild
# sy ale soll sirciss ath aates’slor iy di
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 2.1607
# Epoch 6/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.1039
# ---- Generating text after Epoch: 5
# ---- Generating with seed: " such strife As ’twixt a miser and his w"
#
#                  5
#  such strife As ’twixt a miser and his w
# iel, Ant And I be re (eatreat bedasitz,
# Frated my Bued, I ah ta. Mof bate ef the
#  sing my trayew foot thou amy siky hecur
# yer ne he: seas ot pald bime cithentr of
#  hany cey tolas gioiw. Fol e wwite for s
# oelh wfam manel tloc an meare veakt: sar
# le-s meell shful, Whe cower, Sod seage?
# Aro hour thae (old elfay: pathag of the
# hefe, Sause vose, Igle or the her: beari
# nd cis de hime in efomy wo lofet. Lo t Y
# on with thatcmide ptarmes, Ay mare tima
# becd be, An, Bitut, Arn fie wolch, The l
# eke or mpey cay thes the sart, And bfase
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 2.1038
# Epoch 7/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 2.0605
# ---- Generating text after Epoch: 6
# ---- Generating with seed: "asons on thy part, To leave poor me, tho"
#
#                  6
# asons on thy part, To leave poor me, tho
# us oothide artath the hy reame, Me wies
# frafd now deseing On tilchs, und the Los
#  ullos ot oweder, Thou at ooniib sininsi
# ve, And dos sere, For and of neoss rom m
# y ninh ne realls gime, Theolos Sondigfer
# es, lo ther no henisl gile ald, thy prse
#  aro bane in thy seeperestsose, Phiro sf
# ers’rer thy besey it heausthe, Whis aud
# moweds in thount to yout-te seatly tire
# insmses chan be Tomeslreist st poed, Son
# d it Thald, Aid Whin seworgswsilove yos
# werese, And thou byea bif’y, thoakes fey
# , nids mesessursnot do noef then inc, si
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 2.0607
# Epoch 8/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.0241
# ---- Generating text after Epoch: 7
# ---- Generating with seed: "pure and most most loving breast.   111 "
#
#                  7
# pure and most most loving breast.   111
#  ET tho the brthes wor of lagst the sar
# mo rould hack nomet pan net, But, Syeass
#  to n af oredine aghat. so? Antow mo atc
# uroth pyous nour il dy tiar, houg, Thas
# hone archiss serfis, Sart the ith llenk
# is lomk dast mes patrthen thou sos thrul
# d ar -lope, Br altlicoundsont aotl wivh
# tor dowrosiin dyrr al wir my lovenot ilc
# t to a laven I pour pr llomy er in th, T
# hrecerast in to dare me isew, Where thou
#  hfoukebind ppart, Saw my derein not tid
# e Whe das ligkd peele dove wimul cs blo
# houn ichwyowass of mmterirgresore toears
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 2.0237
# Epoch 9/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.9879
# ---- Generating text after Epoch: 8
# ---- Generating with seed: " will grind On newer proof, to try an ol"
#
#                  8
#  will grind On newer proof, to try an ol
# d, ands the hef right pealstibevorn stre
# ciy, And and thouct time liveron wering,
#  urt iced, ald puct, And tie, ow in thy
# art time my wor dpisp, Tit thst Path no
# thate thcouft my cillsd ditk, Bat ove pr
# ofs’nd thy th that, De thot the ves unt
# tha  folldsur,, To Anath weand mawuo put
# cent gerek) pyited. Fnow bit in now lodr
#  it prtert aid thal whilld, coored tit
# that deyk thou wurghe’str and thy thin,
# jo mith chemcornatat at pans bos on all
# sut ther thy in so tretet cepsty sint mi
# , I wumen tho  ort boveretid tot the’g t
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.9879
# Epoch 10/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.9559
# ---- Generating text after Epoch: 9
# ---- Generating with seed: "em swear against the thing they see. For"
#
#                  9
# em swear against the thing they see. For
#  ealllen amen. O 33  hens thyi? you’s Ig
# hand, For mise duth sues foort for move
# hine? Bot to aBe mrof, And my in the ive
# n thess I migemy bes then sus. And lise
# I of bllinc thut Inoce athew, wrother my
#  pire aft ounce now, Whough) prot thut f
# ort weel, arvoey as reestade thou sodece
#  muse doth thou me with houd mant betsel
# ce,ed coth thot sheis and for dove. a Be
#  math to thou dust to duingurs conisu ha
# w rowe sease, Cove deplove goothin whath
# ameds your edes thave ale seant chofrane
# , As’, To leow: Is beouther hos mote; Wh
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.9558
# Epoch 11/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.9246
# ---- Generating text after Epoch: 10
# ---- Generating with seed: "er speak, yet well I know, That music ha"
#
#                  10
# er speak, yet well I know, That music ha
# te frest, Or hacn wort to beat Me ofturi
# ng aod atd loom in thing amung of nobuin
# d fioch with love nor syeces fichckay wh
# act, I what betort riiseon’s macpind nos
#  pase thewe doed, Theakgiy  han mod, you
# d well stae, Shath on syull: End waste:
# Uth mirt, of oll ut minour, ark such ie
# thige Shat my mos wing, Myes Is ripping
# frawe of tirant in fot, Line, ar thes th
# y heintiy frish leougo all’s beriks thou
#  that out that lolk wape thes bouse cost
# ’id des, reves aode it moos thin, aince
# wirine pisteseoun tout stlevir’ss hises
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.9245
# Epoch 12/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.8946
# ---- Generating text after Epoch: 11
# ---- Generating with seed: "eiving nought by elements so slow, But h"
#
#                  11
# eiving nought by elements so slow, But h
# ermor, Wotn whor he. Whingt is p’ow, The
# e ig mord had, And crathth dy be. Nell l
# ove a 2xaent mome, That om ho llised rfe
# w covenonh my expen’ms, ot thre bransily
#  and thou kessrrats loning prout waoey:
# Yow dont, Thee, For rom blong dattly wim
# l’st stores fast as art thou t’ts shared
#  your sevend all my ato hein thee tith h
# es then, not panker whas Letren do of we
# ll fromer, Wh requ? I  my mperr, in thow
#  notol ans se. Then iloes, rand hecbrent
#  ytare and thin’s ovoth with, That bstro
# st de, For liveys mide nhound a thyant m
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.8938
# Epoch 13/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.8680
# ---- Generating text after Epoch: 12
# ---- Generating with seed: " tired, But then begins a journey in my "
#
#                  12
#  tired, But then begins a journey in my
# cond are dears’ to endeds tite sast fibl
# e cave wien thes: Kund lave.   11n  Whe
# ine ofGsey a deame thee though way exiss
# e of thy hask ble will) If wall they han
#  to leesh ant of mece not beed wigh ded
# het mine, Tay look the tas esest my brea
# rte treed dedses nisal wionae is a not t
# o picr ees viol deafken beane st agl the
# e ton os thee dofide, And you the wirst
# ald suneangat doth hers: And That en bet
# e, As ret is nothend of wotions to veeme
# d suich f houk awern prenead paile. O sh
# ow fow ot aln.  Wht it toy Tham brade in
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 1.8682
# Epoch 14/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.8414
# ---- Generating text after Epoch: 13
# ---- Generating with seed: "e well or ill, So you o’er-green my bad,"
#
#                  13
# e well or ill, So you o’er-green my bad,
#  For If seal gorjnst ie thether? And rot
# ound excering oundnen that hewe thee tho
# u grawe The heac, In you self my madlf t
# hino that and love I wall sell ale whir
# suond’velings watlredss deat? o them fre
# me vinghit thees as theer then shas wimc
# r hace: Suzter wasterse the preac. I dew
# att cewnen thee ight uplour. I sa to il’
#  sey: Frerke nom of hin gall. But at in
# the lisv’s, I ko guit and nofes cfonser
# afome reow, If hoe5 theer ipllive Unale:
#  Ir thie has grconced, horl porss in tho
# e, stours, Time wilt wo’d your die asser
#
# 18918/18918 [==============================] - 41s 2ms/sample - loss: 1.8409
# Epoch 15/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.8148
# ---- Generating text after Epoch: 14
# ---- Generating with seed: "She carved thee for her seal, and meant "
#
#                  14
# She carved thee for her seal, and meant
# daws ncos sail.   98  4e Why sound prith
#  my marth whence thy mave Buviwht des ow
#  do wates I st anders ow miget I firtile
#  troughes nos storakung gume to mine, So
# lld bute-ainly’s haldosand miss but heri
# ng,  whes Hex makes makuld wildecound cr
# ose did stmilu.   48  Pnit to 8t thou fa
# yes’s ip thy love aid domaling se so him
# e dith monf fuld tink. The paid it me of
#  they fors deam-thon slakme slacish or d
# ive, Kined but of this descerss Wich tro
# me and wat be time then enos here theed,
#  And dith meds mirh thee the stast I  al
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.8145
# Epoch 16/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7847
# ---- Generating text after Epoch: 15
# ---- Generating with seed: "ar love were but the child of state, It "
#
#                  15
# ar love were but the child of state, It
# brows my slatiess? But your eyery for bo
# s pend hath you to staiting atse veall:
# Beteig tame and wild what seew-dadine ca
# re) Hor lomt of shellsce. Thou thou the
# shath wirt Hyes, As firy: Thot wits medu
# tatho’s or arling com’st if to’s of whic
# h for de pire, Eaf’n dudmparen that in t
# ay sulowers part. As trone, And the fils
# t sime:  not oth tees hall merssomy: Bot
#  is that sheath, yaut in tame snowlasend
# s deeifnac to thech mame shis percalse H
# esund or dealred: Thif hant: I amose Who
# r frokess of ey mithto’s dreadst and wos
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.7846
# Epoch 17/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7571
# ---- Generating text after Epoch: 16
# ---- Generating with seed: "harvest reap, At the wood’s boldness by "
#
#                  16
# harvest reap, At the wood’s boldness by
# mint, And by some ben of, And look buch
# it the sost the here is io difser do ate
# ts, now what lovr old fores with the por
# , Bur for frrise theue my aments of thou
# gh miss of thee so dilige though shoct f
# rom dithing prome dowhed? be thad ald th
# y lise ay weat reaninp rime, par withtti
# le’s of thou how mode I manton pored all
#  my doad, Siney.   5  Wsthes of shounfap
# e chold wher worss, leaus, to caoiry tho
# u by beaugh will luaks in thou shantort
# awh thee wiel, Thou houghr couth ole? I
# heat neek, Heyrur dhausing I mo, In dasc
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.7572
# Epoch 18/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7325
# ---- Generating text after Epoch: 17
# ---- Generating with seed: " outward praise is crowned, But those sa"
#
#                  17
#  outward praise is crowned, But those sa
# vinc eitiov sumith eruss supist, Mo whei
# d to tirgsestsulios so ruce het woth lov
# e I whemest astownow lild, thou betcick
# as hele, of a weecued in that in beauty’
# s hive To sreay. O’ git unt uncevirs ste
# y datire that be stomes still pitheming
# thou faisr ol heling shack reevass of he
# y, As wat my ald flodes so liok no noted
# ing thul pitwain th’ moot the epared, Wh
# at the saren diif the so abat be tssule,
#  Whine splise, And ald anters’s sall, Th
# at heressting, I seeinde, ow I wase sune
# , Ucruce you hith that the harsecir, To
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 1.7325
# Epoch 19/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7074
# ---- Generating text after Epoch: 18
# ---- Generating with seed: "t is determined The clear eye’s moiety, "
#
#                  18
# t is determined The clear eye’s moiety,
# Aridst elomy my uffeed, Unon the, thilgr
# , As renould folt? Art that ipverie, tru
# lving is And utents thal make, whether n
# ot benes, And a aunce live Sombings ar o
# rtsing Th-eewir blagh, ertey gromy a foo
# ky worth andore thou share, In the thou
# and deded’s ofed, onon acllight one of r
# osch rstellds fremen of the sews car for
#  heck rime stall’s the hichew thing ti g
# ede and mirdo congse lonk’st no foich wo
# t dost I dwingary am thin fon thy mear,
# Thou the sald abpome. Und onewnes stall
# do mice ostroth resive, Then belch quel
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 1.7075
# Epoch 20/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6846
# ---- Generating text after Epoch: 19
# ---- Generating with seed: "which is his due, My spirit is thine the"
#
#                  19
# which is his due, My spirit is thine the
#  grase no whic mort ove tho chirfwed. no
#  ghing, And pyoul’strree, hyel braitye,
# That ploweet strey.   48  Fot thes this
# faily thou dowcot desint stirs. And ther
#  to thith mack But wheise your blay arou
# rith thou beamousco se on the baringe. B
# ut ffaty, And that fristat fair thee be,
#  To thou thou beazbur aild deen, And cha
# ngee race sume, ond lessi’g thee Amy ris
# s, If not me saart of that you hald frop
#  at my peow, Thy luss: For dringenounguy
#  I hast, Ass hather in thy heare, That a
# ll ey seie ald me And hich ret. O  44  I
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.6845
# Epoch 21/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.6582
# ---- Generating text after Epoch: 20
# ---- Generating with seed: "rest and most precious jewel. Yet in goo"
#
#                  20
# rest and most precious jewel. Yet in goo
# d sukmactish the paave thus love:   98
# (fume oway new, A dat to the ghath do nf
# ers) I not look stiels in the dath nild
# bbec. Thensthtill faint my witl in thy n
# ow me storing, thy llow proust wrich no
# allote, Ore for that to goonsed wrige wi
# th yous The face, And bus at the knot gr
# eece uind.   145  This thit thoue aid ch
# esting thy theee I will bloucteming bode
# . But fire’s in thre to to greaser. For
# encrezme I collle.   9m  I this welleot,
#  The grund, Thou wartzet atemines, Thene
# d, what I canked lives in wor dpeavins l
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.6587
# Epoch 22/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6326
# ---- Generating text after Epoch: 21
# ---- Generating with seed: "hy heart which I will keep so chary As t"
#
#                  21
# hy heart which I will keep so chary As t
# hough ridhthe manker scome, For if theni
# th the rake Uncourep, thangee my live ac
# k of toy I fooded. Thes if though shale.
#    85  Wh w6ee thy was ne fanter our end
#  outhing plading shad. For dath in th in
# k hore sainy hame, Und tan Utee, wher th
# y hase withe then ofasurs his praiseet p
# riopy fave truch and mantseess are to wo
#  ghourh no trougrts of aring ot on alied
#  thine.   33  Orryat thin hos destert my
#  hise beaut dnow do mather voot it they
# ald thieg in merund is botring eed not m
# e ben, Ay dat exrouly heprime, And atre-
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.6327
# Epoch 23/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6083
# ---- Generating text after Epoch: 22
# ---- Generating with seed: "looks be then the eloquence, And dumb pr"
#
#                  22
# looks be then the eloquence, And dumb pr
# ime or forther so dich, Tin lose athous
# is best that I hem he deids, And yis bel
# ight mudes gloze thece selents to scort:
#  a romy why leve to so ford’s past ring
# benrkessich ore date’s 7n the xackul sum
# pory to thy rave Them might and no laigh
#  no ays tho lovy as one, lich. Your bree
# , Thy reding, Whore bed doth dose I doon
#  I suplever’s beauther wistl are thou ar
# ce, which my sur.   6 buse I with eyss n
# o store hel exentis steed be do lovy woo
# r af betoess aie manked: when tho grees,
#  And ofe, though my love by lis dith bel
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.6085
# Epoch 24/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5860
# ---- Generating text after Epoch: 23
# ---- Generating with seed: "u art as tyrannous, so as thou art, As t"
#
#                  23
# u art as tyrannous, so as thou art, As t
# he ore you haiving in my see staft ow th
# im not, but their Theacts withrutisg mak
# e, This thy artirn whene forothlight gou
# ll hewrre. Or so lo mire.   15  O2  Le5
# aLit by so love 9f asa i’st are all, and
#  me, olchid dnsersprenour sadk’st dad ik
#  wacce of self your scbed ars que be tho
# ugh not I shadscare, Urllot for dith my
# conklisede is in contie, And gratk I cay
#  he sire.   9  I5  Thea thou me supe pro
# on, To doon, And pantel world. But be ov
# erantee pair if are ooupy eld leacenfed
# that all thou dsour iothing pleastel can
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.5860
# Epoch 25/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5628
# ---- Generating text after Epoch: 24
# ---- Generating with seed: " such day, As after sunset fadeth in the"
#
#                  24
#  such day, As after sunset fadeth in the
#  love tunmer pilcwert, thou macdid; Or y
# out brave Bo wwelf that hecariin that fi
# vet chowire shart, to this fost and befo
# wors of hive il orafaver hear bestace th
# ee that furses of not due ofcesbitueds n
# o elly me yo. Tave ackunee, And veme bot
# h bo yis defow, Break as they sinfld ouc
# etrece. Or thou thou, veastem temetst: L
# ive it repaitiet hood sume likks ’efear;
# s yeo you arbst, thou graatys when at th
# e love’s tweep in they, and efer? Love y
# igey of yel, Utloked theis wert mad, Sha
# t is prisy And thou flowncases of liakin
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.5628
# Epoch 26/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5351
# ---- Generating text after Epoch: 25
# ---- Generating with seed: "de, Or (being wrecked) I am a worthless "
#
#                  25
# de, Or (being wrecked) I am a worthless
# acqueains owellpastor most, and the rowe
#  store asteding paithou witt olether dot
# ame thous powss r-im my ar woll what eas
# une doth dosi, Utllve worth thou artarth
# es thee to mimith that to lack leve your
#  mupen my freper where in corncingion co
# mes with fipling of sank and the lads Mu
# sts, What whef owat, The  ak sherterned,
#  Utle creadry Me. Yot is ily thou shalti
# th mine, Iverceeps day parse, And for av
# e graescish the wat. Manded past do part
# e sink of that stall they fo7m still thy
#  mad’ss ataming thau stalt, whou deasure
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.5351
# Epoch 27/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5095
# ---- Generating text after Epoch: 26
# ---- Generating with seed: "t in walls of glass, Beauty’s effect wit"
#
#                  26
# t in walls of glass, Beauty’s effect wit
# h shoull dook, I leen that greated-ounds
#  of freme year and flower, arl vace thu,
#  say with ivengeise. O  m1 Is For thou p
# aip Unong defoul wild thou (mine rear pi
# th wit leck desend: Which enthientrow: L
# ove cumenf am have forth, Ast and rear’s
# t stal: There brtelleds minish bead, And
#  fell when dn eived had ssulf cond it ne
# ay ease thing pair, Thy price amlint. Sh
# eer onter, And tinse of makes endeed in,
#  Tun sime, Which lipury whan my are worn
# d, tillly, To cowear deides kint, Une sw
# art crained in the rund eyes steed: A th
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.5095
# Epoch 28/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.4852
# ---- Generating text after Epoch: 27
# ---- Generating with seed: "lamed shall not be thy defect, For sland"
#
#                  27
# lamed shall not be thy defect, For sland
#  eye dote, on the new my prougle sank, d
# eath radse my touch a mungon id slosk, b
# e fecellong: For from thas griwh to in w
# o creaker noth bor) kends you hats hy br
# ense windiln with thees sweet cane, As f
# atiy tibloth duch fair hece: So act kine
# ? As thin the bay to suming stall death
# the our, Gich-tace and hild out beay, An
# d for if theyef giffor youth that guld a
# s aflo shaet-boon The butainot for I am
# mady are yous to tam froe.   65  All my
# dost ole pays perie to watly doot shall
# soll, but a failline to My tome I sutine
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.4850
# Epoch 29/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.4588
# ---- Generating text after Epoch: 28
# ---- Generating with seed: "nger nurseth the disease, Feeding on tha"
#
#                  28
# nger nurseth the disease, Feeding on tha
# me dis bear: I swaet uren that greos the
# replove hank it for fined, And thim my f
# ill whilft to king, And light spuiving o
# ne sbeer, And yous swory, ’stire. Ol sut
# h that I commone. For war then will ravu
# rt to my trone, Grine but to arpotwer.
#  1110  How mu gunten to ras ot ol utour
# cay manes thee ason, Then beculing stitl
# ed, To  ais acherat in theed wore, Then
# what woth light? Yet lin gnewted, bul in
#  the race, And kince with leature, Whe w
# orsur barsing that stent frime renoury i
# g naghanted, Or mo thy hise exenes, Slue
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.4588
# Epoch 30/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.4304
# ---- Generating text after Epoch: 29
# ---- Generating with seed: " sole effect, Yet doth it steal sweet ho"
#
#                  29
#  sole effect, Yet doth it steal sweet ho
# ve helisgoter heagh , gall blome’s quist
# , bet post-to doth faithle hill say out
# the kinged shy day, Or to motiew set at
# heed, While not thau somawery, Sinly to
# still, To dit live thou shy true flower,
#  whe hough thee, Tho heartive. of thou d
# ayss have penferse to bet’ed unfore he s
# earsescoor ninging on learted, To be of
# the dost fore: But forment’s foon thoued
#  love the deweed ot my blows in mine.
# f4  Oo wo con ippenuns of me.   49  Thy
# dise hot my shall me some I mast ipventi
# ng formey whech vos, Why beautur come be
#
# 18918/18918 [==============================] - 44s 2ms/sample - loss: 1.4306
# Epoch 31/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.4034
# ---- Generating text after Epoch: 30
# ---- Generating with seed: "re than enough am I that vex thee still,"
#
#                  30
# re than enough am I that vex thee still,
#  In thy sond can For what boly woll all
# mores of buld foll his stat ot, Helfose
# dost lupkides, by a liy not foring in il
# l bun ant to guet’st cold wheth nos sten
# to’s seld is theng not sa, If ffret, tha
# t band near pue lill greise. And to thei
# r sprtiniss, And he paizeauth’s fack sty
#  love cank dut this (pin my love, Cony:
# If thy selvimv und spey.   120  But gron
# g what I me goast thine ligh eys, As des
# ceit of my noth foulds thich avlave can
# an are arounscotrent, That faizet, The h
# ering shall daik fpank rement, To blad e
#
# 18918/18918 [==============================] - 42s 2ms/sample - loss: 1.4046
# Epoch 32/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.3771
# ---- Generating text after Epoch: 31
# ---- Generating with seed: " Attending on his golden pilgrimage: But"
#
#                  31
#  Attending on his golden pilgrimage: But
#  whos arce) not and are worte. Thou tind
# ; For bears on hel A ford no retare Thee
#  say, ry mid: Bet to the scont fain thou
#  art thees on on my pile ofques and beai
# ghe more of in the bace.   40  Hew bot a
# n ig thous it edvorn to bet that wor, I
# dass froomen wit thy sisen wothinging fa
# mon speid nea thee.   111  Inf e fe5 sof
# orece of the prowblen sweet Is dowcrqugh
# ile, And his paintour cornd so, Than had
# e, and thou ner deamed me when by arotis
# s stren.   97  Leak ithts thew all her p
# raivie: My soik all me ’geceined so mo s
#
# 18918/18918 [==============================] - 44s 2ms/sample - loss: 1.3770
# Epoch 33/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.3492- ETA: 0s - los
# ---- Generating text after Epoch: 32
# ---- Generating with seed: "rness of absence sour, When you have bid"
#
#                  32
# rness of absence sour, When you have bid
#  thou days stall, but ferrver, Wimm you
# art it all thin thee, but a byef-lice, A
# lay, that dif hid needst) thre, Doth whi
# ng ting, And sith What formlound, leant
# minet? O  634    44  On the sunter Mast
# glowsing nath I suifth and racking inour
# e worklows redouss jows of lave aser, an
# d all then she wainds bray, Sumend do th
# e potce by a faplling whour sheed, And w
# ell ine, At st infue to thane, Thou mind
# s wholr bloven that I howe sher poilury
# is ther is there injuld you hich all, el
# l than shalt day, Thy with in the brend,
#
# 18918/18918 [==============================] - 41s 2ms/sample - loss: 1.3495
# Epoch 34/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.3223
# ---- Generating text after Epoch: 33
# ---- Generating with seed: "her mournful hymns did hush the night, B"
#
#                  33
# her mournful hymns did hush the night, B
# oer pleenie, On the plove a punfig taye
# suefall mome in learth is the rese winca
# mest cose, For face detich for leasto so
# my to live here ode bue with love, Why s
# tcered, For frhel to that love your beli
# vy ankis time hose of, are these dormect
# , Since hot wanvesthars, And brufeit ous
#  to asseds The face, That heart for many
#  alls girst proves thau (then their swit
# ternd is ndight heis out is senvingt aln
#  me and that My mide Ringth’r? but for w
# hen were beaugies’s night, Than therefou
# ld sckeldcd, That I hing shave, On from
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 1.3214
# Epoch 35/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.2950- ETA: 0s - loss
# ---- Generating text after Epoch: 34
# ---- Generating with seed: "name, And in the praise thereof spends a"
#
#                  34
# name, And in the praise thereof spends a
# nd the heart, Tay arthourl blocn yout ol
#  queatint mo dether detios, jinco shall
# be firscted) on leact cellocr dut end co
# me, and sle lie, And thou deepare, Thay
# sem lle so learts of forf is aslong do m
# y his se. If hat ot thy love thue headen
#  nos thee aldok of halt my belot cheeed
# will bpained told. San I nou suavi, then
# es me, bue shaitate which mary he vorce
# spurd. That whereap com the pure tire, A
# s themere se old mar; hen in the requave
# w, That ferss bet pontre, And you hes wa
# ndo sherse Then thou inhthours bear, Thy
#
# 18918/18918 [==============================] - 41s 2ms/sample - loss: 1.2949
# Epoch 36/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.2667
# ---- Generating text after Epoch: 35
# ---- Generating with seed: " gift thou shouldst in bounty cherish: S"
#
#                  35
#  gift thou shouldst in bounty cherish: S
# o shou to’ as allonger, bo hin thee avin
# guriess os of your from thought, thou ar
# h arace alday: Be uven theremofes to me,
#  to tay striss my a sace thy price thus
# diswifle With a (metine by woild alothou
# nd, And thus tond the day no  wencied co
# ftly love, that recas. Nowryev, Wh the
# thou frosel: Ifther wio shall nought I a
# y as breated to to moted a bestrot, As t
# how will ofealing plove thy prousyous: T
# hen my seas to the puntin condon, By a t
# hy ustan.   128  Whill own I allat, the
# verce of flomse frumenc? What best’er ha
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 1.2666
# Epoch 37/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.2390
# ---- Generating text after Epoch: 36
# ---- Generating with seed: "eem false in this, That you for love spe"
#
#                  36
# eem false in this, That you for love spe
# fer is the ’st rovn poon in inceaned, An
# d that I showf in the stres, thingh beau
# ty’s anstor cleast of my silf to  oveesc
# eacing mand, Sequlind come I roskest, bl
# y days, And gelse filll not eass Of ad t
# hy scorted innore? Foud ey ight laving c
# ould coll, Mading thing gapd’y frase her
# cends fommentrowsing thy lave by gaintat
#  a king of chinge ’grikny so reim deinot
#  conlingen makrew With und no resboty co
# me rome, new colfamed fresloents fowrell
# ed that conforse, Be. Hy hiss, Sos a cha
# nged I self thy desanter of my heast ent
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.2386
# Epoch 38/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.2100
# ---- Generating text after Epoch: 37
# ---- Generating with seed: "more re-survey These poor rude lines of "
#
#                  37
# more re-survey These poor rude lines of
# priage of somflid: Which not mine the re
# me head, But by sime han my tamb to thy
# pold seffll glost pinetings, Thee ivetre
# d as ard greaberurn bmome gindmest, For
# live’s now. I now Whougit nancesling, Wh
# at ot making wight.   149  Wos noth rase
#  my with So whit yot come of my not love
# s Unter portw libe, She dos stasines At
# masust thencts dut maving thy lave’s con
# k, is arse chavgey not to my comk I coll
# ome, exen packery Peafth nom to botimest
#  ipwellecs handil the ble, As dath heart
# , While be tomave with zobt forms do mat
#
# 18918/18918 [==============================] - 42s 2ms/sample - loss: 1.2100
# Epoch 39/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.1792
# ---- Generating text after Epoch: 38
# ---- Generating with seed: "ten of thine ten times refigured thee: T"
#
#                  38
# ten of thine ten times refigured thee: T
# hat I empnours no more lave siffll now f
# on my senf wothr, marestould gives ploss
# ed in the reme of with, oll hid? As thy
# vindted dit sauty’s howr nightly witls b
# espic colly loagion baress. Then forte i
# n there not this mind, Macred, In los yo
# u my sigt, on .  siwe first what as thy
# self celf, that yearing be, Tipstine, Si
# ll, new, Shalt flomth that the paironed,
#  Whit as the bron, Piscutied douth fremp
# ore to muckeds, shall story lave, me arg
# und’s for live, Ore mate with me stimint
# s. That me se prspair. For thinge so, pr
#
# 18918/18918 [==============================] - 42s 2ms/sample - loss: 1.1793
# Epoch 40/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.1502
# ---- Generating text after Epoch: 39
# ---- Generating with seed: "ly I think on thee, and then my state, ("
#
#                  39
# ly I think on thee, and then my state, (
# ’e ounted ewell mowent sheec. When worti
# th be betmore jofulings in thy sif, you
# in the eye, And for have frome) and do c
# ome no knows I not tas mine heme pall th
# ine.   140  Adly most vexcuese whereveat
# h dear, all tyoue thim thou marnter, que
# stined sheetirg keather to treaven of th
# ere In calay’s mest vivel nouldestn it o
# le, Bel brtine hid aive umingt, and well
#  Utle not thou suct pealing Withter’s mu
# st, Or boby wince saif, ot me bences the
# e, For be the siget, That flower thee as
#  their chower eftreinne so thou hadteous
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.1500
# Epoch 41/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.1214
# ---- Generating text after Epoch: 40
# ---- Generating with seed: " and the counterfeit, Is poorly imitated"
#
#                  40
#  and the counterfeit, Is poorly imitated
#  pread, and chanker with selvery sequeds
#  mase: If mare from dranker with shall t
# he fair or thire.   g8  If me way shate
# foun this cometrins, to my mide with bro
# uss, Whot I how’ thou art holl not to my
#  coll with injuer, leagting me still fou
# lds thencencestest me.   185  In so hear
# ine a  w20s, My noth no your portld, Fer
#  alling thy diec il hach, out not seth m
# ower’s in ill me in’geathe ot and hase s
# hamentien so their chater of my muraits.
#    f49  When in lowe away that love here
#  my deam nofreppind thee, The eauts ot m
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 1.1214
# Epoch 42/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 1.0956
# ---- Generating text after Epoch: 41
# ---- Generating with seed: "ye loves it and doth first begin.   115 "
#
#                  41
# ye loves it and doth first begin.   115
#  Bls ivure worve burife, For wos fotel i
# n the gied not sun times the atcrep: Bet
#  wo thou fill, For shappabes comerce, pe
# lly borthould, Be thingue trenked of aco
# urt, The Oee dot might plaviry herce vin
# oure, nild? Lilf that belfes noth) giet
# on all thou (this for the oneadot chened
# : That fair far for to greated dout and
# oline? wherevill thou dist boly momedst
# me worth And wot storing not time, id ti
# ll, Bet thorow’s forses afmenced ilfay.
# When thoull gooty in miget, And love onw
# er prawieh morssowsen, But is eas upnene
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 1.0952
# Epoch 43/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.0659
# ---- Generating text after Epoch: 42
# ---- Generating with seed: " face should form another, Whose fresh r"
#
#                  42
#  face should form another, Whose fresh r
# enjunts of sec-ainuane: Surtay yout even
#  and my Ford thou sew it ot your maturn
# thur heart manksestrich the reppime.   1
# 81  5 Moun ayos maken ay se.  swansw, ro
# ss of thom al thy self your not de.  af
# thy preanored, Asstiet’st, that woth no
# supeanth, Thos hes grays chowame was str
# eng th urtootace upoe the bunger, Make s
# haming a thou dast bee, To al tond.   5
#  I suin a feye sine anthe he riend, coll
# s that least to seveed lige that whrich
# It fower agare to they mighth’s gives it
#  inverepride of my love, I hald, Shall g
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 1.0660
# Epoch 44/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.0332
# ---- Generating text after Epoch: 43
# ---- Generating with seed: "ols of time, Which die for goodness, who"
#
#                  43
# ols of time, Which die for goodness, who
# ugh my hearts face fane your your stance
#  in woll quist tint, And so whou do the
# gurdsestring aguts ithou doth hel smife
# the pairing day.  Thus betinust ey live
# herl, And in thy in me whing rave, Whre
# fort, when thee, Ore that suek, And swea
# t of thy spurt the fore parout hyout, an
# d ast me antrome renomy, For my bair, Th
# iight thou plabler’s did dive, And ont g
# ustexed buds luss, The winnesess wilsour
# anked To rooks The fure, And glowt fairi
# ng be. Thy ally are doom, vorded when an
# d moth pastuer ers heaven thinger wot of
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 1.0333
# Epoch 45/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.0084
# ---- Generating text after Epoch: 44
# ---- Generating with seed: "do love thee, Till then, not show my hea"
#
#                  44
# do love thee, Till then, not show my hea
# rtn of strangered that lonms byrnecoly a
# rauge to bearted thee faar, And for dost
#  plove, recise fou whole beliguts to thy
#  uneds sweet ipleven hes bend sut destor
# n. Leverteen mort? Made now leys not not
# h one of Lose a bear to love (mend’ shal
# l my hooker sonk, And ath need s bf mine
#  in my steed ars be sime reen. Then th i
# n the ripire I thele in me, on theness w
# ith that thy se.f dremerned, waild booth
# )’gh his mo, ey, Unl: Whyse brank of thi
# ne sofll blove? When my creauly jemeaknu
# th of eching sime.   64  My or wool sukn
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 1.0084
# Epoch 46/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.9805
# ---- Generating text after Epoch: 45
# ---- Generating with seed: "on the way, When what I seek (my weary t"
#
#                  45
# on the way, When what I seek (my weary t
# heage and trave I him more, what is bare
#  pans acreappsing bedy ? bet worn an lea
# rs for finnt? Nay the sternes, And lides
#  the cainlingt? Whot I dith thy me trume
#  do, prooving ne. Astireco by a cricel h
# ingends seals plave, then in sue? Do tho
# u arait of tame oftering Of luvest, lyou
# gus graws arpactide, Thau eavies ungen s
# o hath no ramends facr, I (doosy not tha
# ngis makiey suth nistord, Which sich not
#  fremence bring ’st flowerver east of sp
# uel ne for of this Give, I jears of the
# croods my days fiom my time lose thou ge
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 0.9808
# Epoch 47/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9555
# ---- Generating text after Epoch: 46
# ---- Generating with seed: "ly bower, But is profaned, if not lives "
#
#                  46
# ly bower, But is profaned, if not lives
# anginges with thou arturee) beruth) onge
# ace, And mode lewest not in memind, Reid
# , my bradse be mingr my live I the’s bot
# hinn. Thereanserseatle sught all tor to
# suets a days all blooks to reverve, ‘Til
# s’st thee bartw thee berivel words my pr
# enous the raskes aiveroush no hang ther,
#  And that thy dowe leart, Thenchim nepst
# renst, When my sean inw,rand. Th mis as
# witlough where in griet, And woll in tha
# t ell the pores I mescrase, be thou self
#  hish arazest but and my heart, There ke
# ngus beauty but in groakly dichmory, In
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 0.9554
# Epoch 48/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9297
# ---- Generating text after Epoch: 47
# ---- Generating with seed: "e that there was true needing. Thus poli"
#
#                  47
# e that there was true needing. Thus poli
# th unument, Whill firted’s feess id mide
# s in the realles with everr bre woll aft
# hrented can thou brace his can whoul gro
# men fake no loik new least sike And have
#  duth with itbure to show all the braund
# e so flace, leath redouge to call byou w
# ith ivew in grete ele tornd, The eases o
# w faccerure the encestline of you, For i
# n touget with thee athar you hads ot ent
# re tull thou sellasure thy uring bear I
# cack amace from det my so.  a1viefur do
# thes fill hyrefing be of the grances eye
# s me not to gaven than thou thou thought
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 0.9299
# Epoch 49/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9027
# ---- Generating text after Epoch: 48
# ---- Generating with seed: " your most high deserts? Though yet heav"
#
#                  48
#  your most high deserts? Though yet heav
# e bad thper they past, And you Grte mine
#  ot int ont enfur do the bus, And on han
# pers formote? For he seecaingw, Whill in
#  me it reat me in where wotld with he wo
# r’st, Ors bla in weat re-parted, That is
#  out of grige. Thin graisy theer but aid
#  and beauty acon thou too all, mitht in
# me when blo gill, Uncour in willokine, T
# o cook’s no qeic, And no hatked in the r
# ack ne hem thy love, If my toust? So wan
# t overceatien When black innule in well
# purning on, all dat eir stat it conk be
# of my sour pelve? have I nongerserise, T
#
# 18918/18918 [==============================] - 44s 2ms/sample - loss: 0.9026
# Epoch 50/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.8766
# ---- Generating text after Epoch: 49
# ---- Generating with seed: " to correct correction. Pity me then dea"
#
#                  49
#  to correct correction. Pity me then dea
# re live be oftell breed soun in love as
# hine.   38  So in antin the deage foll o
# f to toll, Ull I rears fremences will th
# is contains. Such arle this con, andicgl
# y joms det I facer-with shath dact deam
# not in meauth thuight theres. When thy c
# ome deteloks by un in my for fat urien h
# in marred and heart Of sirne, Whe pore h
# ees met’sl mide, And you, Withou aros ag
# lins. Swan beate’s fair my perjored of t
# y wit, Shat I knot my seef lipen was ivy
#  sam strege. Thin seath inforay, That ha
# ve was me wore prose ele finted the rey
#
# 18918/18918 [==============================] - 41s 2ms/sample - loss: 0.8769
# Epoch 51/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.8485
# ---- Generating text after Epoch: 50
# ---- Generating with seed: "le doth thy beauty grow, If thy sweet vi"
#
#                  50
# le doth thy beauty grow, If thy sweet vi
# dtelled oll me remipe. Thy beat with fic
# e.   63  Gillthour green was woll lele p
# ring: And worth do the comelly makes in
# whick ot my in the shall miser are subft
# h, Uml of the brazed erd buth and samen
# aftyre, That askedsefull madery gried, T
# hy rell marest And so raze) all than to
# suft’s raight wamboong live to premest c
# of thy serksime in his mothines dut pong
# ue in my love comparn wild fare loty lou
# g’s orthes what as rement, Har, yet blac
# k)unssoworad? Why looe anghou are more t
# hanch of el’st colfteed, Whilst comer my
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 0.8487
# Epoch 52/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.8287
# ---- Generating text after Epoch: 51
# ---- Generating with seed: "e taught it this alchemy? To make of mon"
#
#                  51
# e taught it this alchemy? To make of mon
# ds my stell not macbery all me heme.   1
# 85  That thou fail in ret blozed to be t
# ild, Lestu, I dmid othinlt se, mur’ wher
# ein mifue the faomed dut min’s marrel of
# e, And hidst his own make why freser wit
# h unting my will. Ave it en that thes fa
# rs changer night yet be, As that heall b
# y a vise win made, who conce) thine, nor
#  sith wo be tho grecish my hear’ tyrap m
# y hide ownouns of the wassy wo be thou d
# ast dipen. O wart wo cow? Yow enoud d-tu
# ch lows doves when thou art doth hease A
# nd thing the day, To king shalt hin my p
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 0.8287
# Epoch 53/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.8054
# ---- Generating text after Epoch: 52
# ---- Generating with seed: "y where: Then were not summer’s distilla"
#
#                  52
# y where: Then were not summer’s distilla
# tely, I dotse Grouth to thee, That I am
# stirture ot me forr furecest do. hark: B
# ut in if for for for the primen your pri
# se houd: My crueds are and maser shalmin
# g on with by cime sen more. I nas ou the
#  worth prond, That I congooe, Whilmon br
# ooly seme, What thou dist dowe, And more
#  lowk one graws and excry both no here m
# aterl. And to to thou thou grows’s dound
# . Yot then the mide: And thou det, And b
# ain.   71  I ween wethin an a beaution s
# ight, The eases of afonty I virice? que
# that show, And boot pliamen frar chooss
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 0.8053
# Epoch 54/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.7845
# ---- Generating text after Epoch: 53
# ---- Generating with seed: " know, Then can no horse with my desire "
#
#                  53
#  know, Then can no horse with my desire
# .   36  41s Wo lo it in yete, as farter
# hinving that glowy eace a foeme reime, o
# n shows that heedvericesthingh, And in m
# y love showhane. Sweety fiond gived the
# bit that be onceepous thy respaire, Why
# bleck dipmeding owestill gith: ow flo th
# at frookle same mider-fice, The ersers o
# f the sewnot layss wattr to muscrooss ba
# nd, No kint. So wort borr nage werre lov
# e him neir foiring nepride, And you, tru
# s parauge thou ar fatt’se the comeling d
# eather’presenes dost seen marr heer net
# thee.   d49 Thy air what power of thees
#
# 18918/18918 [==============================] - 39s 2ms/sample - loss: 0.7851
# Epoch 55/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.7603
# ---- Generating text after Epoch: 54
# ---- Generating with seed: "n and so rare, Since seldom coming in th"
#
#                  54
# n and so rare, Since seldom coming in th
# e plazef-light’s tore, So love that hear
# bled paisere Or, blough thou art hooper
# detent of leattoweds, Have forchspise. Y
# ou wirteet me, more debevine is prene Th
# at enting perted in with inverrive, When
#  black cul by miguth eylight in my prace
# , Kilh with my doon fice? De with not do
# st blownow, Bean yea hers to greater eas
# e for live for orn to trear.   140  O  w
# hen woll affievere whrrewered coll in wh
# en the seasks at beraldeate than The loo
# se, Thin same spred. Then thy mer that I
#  can more dothive mus the pairew, Ind wo
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 0.7603
# Epoch 56/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.7321
# ---- Generating text after Epoch: 55
# ---- Generating with seed: "t if thou live remembered not to be, Die"
#
#                  55
# t if thou live remembered not to be, Die
# f like end mury, Unl sush and gie are th
# at have but thy seef a ackeace tomstich
# of ay retelscouch, Nor thee that tond: B
# ut when ipprime than genceld? Int that o
# ther, As what more whan gruif-ist, Be wo
# rch ore woll they suif’s firs. That I mo
# ...
# facke in the wart, I spood yet’s name wi
# th vilm thou as thou polloust, Befeccric
# h thy win.   140  Twillok I shopist: Tho
# s sarse thou stoe? how in the plosking r
# ank, For it reting fousd madred. Then in
#  thy seencess basuong ow efcraced. Then
# first, Thene his love your reve, Shost p
# rigel frimer.   15  Bus in the beauty th
# ee thengeature is then.   140  Ty shos a
#
# 18918/18918 [==============================] - 46s 2ms/sample - loss: 0.3896
# Epoch 83/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3834
# ---- Generating text after Epoch: 82
# ---- Generating with seed: "cked I matter, that enfeebled mine.   87"
#
#                  82
# cked I matter, that enfeebled mine.   87
#   Wher the sin the gaiment, That love yo
# ur pilt thine in thou dost boot, For his
#  betance to comescreise. Theise preass e
# nfrich An the wirth No thee, No thou fir
# st Hiref in worte, But in toul’st sturin
# g migut, that I cold the dete do made, W
# hin the raigel hather doth for mifure th
# e cime daisur’s see, At in thy sinsersty
#  that hadged our finsere thum thy loague
# e, And given theer moth prown broust? Or
#  ot uinties with a beauty hadkeds oll th
# ee acheripiou in wheme for frookle aind,
#  Be’ where’s end, My sivet it come ploon
#
# 18918/18918 [==============================] - 40s 2ms/sample - loss: 0.3833
# Epoch 84/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.3741
# ---- Generating text after Epoch: 83
# ---- Generating with seed: " And therefore mayst without attaint o’e"
#
#                  83
#  And therefore mayst without attaint o’e
# wverve, dos aiventilt muning dot, To me
# whon all, on all ove, thy dear deth wort
# , But form thee, Ind such uppince plosie
# ds that then the decuese, And can I deti
# nce, or my so., Brt thou a caver, And ye
# e, Atd with adow, Wo dot Wite the wart s
# eef lave, net thee.   140  On what us if
#  then sagf ow :ougtile in thee are, And
# grown eye love that he wirnot, when I  m
# ow, and mur’s thou shaplithtous are so f
# old What bearth’s plsament hide, The lac
# k, Her past, And both prace ance, nor th
# ing ease leverve, For in the come: I lot
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 0.3739
# Epoch 85/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.3818
# ---- Generating text after Epoch: 84
# ---- Generating with seed: " scandal stamped upon my brow, For what "
#
#                  84
#  scandal stamped upon my brow, For what
# It mind’st blawing thuu that sen my fros
# se ring, I coussunt from your gries, And
#  fan ey be tiens my forst being perir wh
# at it dothcess bue it mer.   91 ge’me fr
# om yrue? Oh of thater why heatting neamo
# not, If blough thereak of lowe’s fearth
# trich must not so, opweet, That I not mo
# rt foll, Thanguest in devint, thou that
# fair changer proov’s firsen right? I che
# riture thy loagued of hy deead’s onceson
# e Riscestiel my heart, And that I callot
# her, or though your lake have doth hish
# brould: But what you are Ornowside.   12
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 0.3815
# Epoch 86/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3710
# ---- Generating text after Epoch: 85
# ---- Generating with seed: "ed be.   139  O call not me to justify t"
#
#                  85
# ed be.   139  O call not me to justify t
# hue praisy, Unl hy sints’sthing king, As
#  do the stail. ’ay ghen fors it thy part
# , For loving hish might the cangring wit
# h Why lobge the lige untreinge some ploa
# king with And with self,st’s hire out en
# jughing ’stmiss to mist, And virgue and
# make a viom frimer from thus love’s be u
# nterper day scoons aword, If all the str
# ong eaks murairs and of feart, thy prais
# e. O if thy it in the resplisp: Ald what
#  you praise, Hawnon me miger hath thy lo
# ce and dose love that love thy not have
# days, To ack not dust live? Rivessing be
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 0.3710
# Epoch 87/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3601
# ---- Generating text after Epoch: 86
# ---- Generating with seed: "est. In me thou seest the glowing of suc"
#
#                  86
# est. In me thou seest the glowing of suc
# h how he deating chank datk love In wrin
# c, Not I smors, Tild befast, And wor fea
# rt I josceat, thou dust live: My firel,
# facme in whathough thy grart, Shall giss
# t unfought gances wo ar thou fidse eas g
# rould? Bowhising and dost thy selves sam
# bll bring not dost beauty, Must leavente
#  encelving ofay post, And ome retelming
# know quicksling, And luve thee vereweot
# sumf ind thee hatter’s thee, I love us k
# now in heart’e  adnour toutath thiight t
# heir spitire, Or ot me vaiser frimenus’s
#  of blong, And that I not morn do then t
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 0.3600
# Epoch 88/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.3475
# ---- Generating text after Epoch: 87
# ---- Generating with seed: "th sides thus is simple truth suppressed"
#
#                  87
# th sides thus is simple truth suppressed
#  sam As that excust the fair, Who mar th
# ou for in eye, Well I last will our will
# , But if their douth thou art thou showa
# ce, And dowth fur fankers making injught
#  heart, And impuneds by siet it stoon wo
# rd, Sholll I to that thou ar of suce? he
# r my wrtak of blove, Unt a suasi y usise
#  have doat conjort: Whill how, the rece,
#  of an of thy same: And for for him you
# hersecd ofll morm. Thou s if hime’s make
# d the bet or hall, And give and good, Th
# at fair f ar blast reipoull she lich cha
# t mellights thy respore, If lothen are m
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3473
# Epoch 89/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3622
# ---- Generating text after Epoch: 88
# ---- Generating with seed: "e world’s common place? Or mine eyes see"
#
#                  88
# e world’s common place? Or mine eyes see
# . Dot the pluatieh he badser’s praise th
# ou stastation virt, And ben st berve, Th
# en le mide, And thou he be tho gast arcu
# aind, And worth remeas to rayss bory pra
# ng thy bund, ey live, than the resens ab
# onk.   d32  Tillous near show me dot me
# orhervert’st, Which ncumber which thy ev
# ery are for’ acfearing aglow? Whot I (me
#  fordot bengeav’s ripwid.   132  Slan in
#  prays leameren wofle me both innoes, Sh
# ould the all yet for frorded stouthes ch
# eseraly grawss trink on that murats’ the
# nele stant me wast thou ar oweet me both
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3622
# Epoch 90/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3321
# ---- Generating text after Epoch: 89
# ---- Generating with seed: "year set, Like stones of worth they thin"
#
#                  89
# year set, Like stones of worth they thin
# k paintie, Of verver fair feart, Thine i
# n the pasten fair fairen whan they in th
# eir sweetred amand namker) alo’g Uell ma
# de, And you not seen Bay, Utl it yout ed
# venture? with the gise can thy love, you
# r come patien fon reary when the prome,
# As fate here vorrst bugainst is be regei
# ce? What Is the pare worst, For do not l
# ove thou dist stous it love be astore, W
# hereith thy full why fioss, And in heart
# h d’e lot es that youn blight’str-cast I
#  nonk Il virpwertord colldiey, or vilwor
#  seen but the probainge are beling swatt
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3321
# Epoch 91/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3470
# ---- Generating text after Epoch: 90
# ---- Generating with seed: "d in thine eye, Therefore in that I cann"
#
#                  90
# d in thine eye, Therefore in that I cann
# ot makins light, But finser dainy: For i
# n the see of realty nut se fatgule I dow
# ch notlisht, thenean wasther heart’ then
#  that spank ot sour might, Soult the pai
# ne.   8 w 6e this as a fane acchath rher
# e, mind, Deal shoplappind madrer eyes le
# amune engon, Who mory I that to leart’e
# song Thy being see. Sweet the oweres bos
#  mades the liemy wher’st I mascoor blove
# d, And yet with thee maruth trut dust lo
# ve advinst, The can my self chldver, Mot
# h that you heis sightsuptime? Nay that p
# leajuy gintce cold can my ealugus te bea
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3469
# Epoch 92/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3381
# ---- Generating text after Epoch: 91
# ---- Generating with seed: ".   13  O that you were your self, but l"
#
#                  91
# .   13  O that you were your self, but l
# eades ben scornceys’ unveot, Thou fair f
# riefrerver’s thume love thee, new fremen
#  when thee worth distring not thee, Wher
#  blangien, or aver pronn nfand, Thy frin
# gh of the spest, Fromel of hel they, ald
#  yet, In gaest brongs, Or by dith live’s
#  night, That theness can my powar of thi
# ne nothipy buet in my love a fieek fon r
# eving, anddemed, Whill ot me are tooly m
# ure then I  touth evins with he bur mide
# s arfove, Who fort, Than staltere, And g
# ive encull and duetcress To my come of f
# acel. How my fidee, As what bothou senfu
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3380
# Epoch 93/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.3276
# ---- Generating text after Epoch: 92
# ---- Generating with seed: ", Or captain jewels in the carcanet. So "
#
#                  92
# , Or captain jewels in the carcanet. So
# louty the tore bother; But the geaties a
# nd sweet all the bet or have as ronk liv
# e my forsune hin toust, blankinsts, The
# bre, Thy daiser thin see. Yot if the bet
#  as first ring be thing that hes me worn
# s mory frord, Unl shor’s do chese flome
# thinds graws, They livest safe sconcesti
# en of he reavel is adrich wherevowr vidm
# e than they live, What ot looe, See. Yot
#  it in the werce of fair why finds endio
# th, Thou ar was afay for ferrere What I
# beteraps ard can my wort sweet behantert
# s fart sufperith thy lines greating prom
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3279
# Epoch 94/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3220
# ---- Generating text after Epoch: 93
# ---- Generating with seed: "be my gentle verse, Which eyes not yet c"
#
#                  93
# be my gentle verse, Which eyes not yet c
# rien When the sweet bain, This bendss th
# e baimed the ringure of thy sweet hear n
# ot thee are fones of year, then the boon
# se. Yot in freser is thou fearther mide.
#    32  So loos ari wat you hore he watty
#  which thy nearth on the was dast sill b
# oon, on the priss. If ffatll fiiser, uri
# ng in thee, bur trid the parter dutien d
# o thip blacker, A an thee, not for feart
# her vilpore all keen he peakine mory pri
# de? But the semand Pin me paruted fild,
# St youth then thee ach) res geature il f
# rormercerservere, tords, That ill thate,
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3220
# Epoch 95/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.2914
# ---- Generating text after Epoch: 94
# ---- Generating with seed: "er   29  When in disgrace with Fortune a"
#
#                  94
# er   29  When in disgrace with Fortune a
# m thy pair, that wat ehoull byoun power
# il hid trou ar-it queasins on wilt. Aod
# youth antrestur virt, Which not matied d
# ot me iothip, And ble spaiving agu thou
# wastain. O nat out this fises, And with
# price thy ben sam now Wifmer presect on
# veceld viour no bain.   140  Twneath tho
# u broush whith thou artund to coldor’st
# fance of love is bet that pottrine eyes
# I  woist will in the beauty bair, That f
# orsenowy quec-ic. But fworts of blove’s
# and not make. Fow thy say Ast more deser
# sune hande worth do that I chookid thinv
#
# 18918/18918 [==============================] - 35s 2ms/sample - loss: 0.2914
# Epoch 96/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.3352
# ---- Generating text after Epoch: 95
# ---- Generating with seed: "ost most loving breast.   111  O for my "
#
#                  95
# ost most loving breast.   111  O for my
# soul friser eyes many heart un the passi
# ns from ylu bords to stath No retlme abo
# ne. ’gracies, And for er’or paintien? Or
# ufthines Hadk) dippint the curpent from
# their morled was on the casse corteal mi
# ghts thy rime of my criess or baddore In
#  wrend lid thee, And bel’st, thou seekno
# t for heves Theill in her they thou (ald
#  that live, That I callot confeation com
# ay thou art abthat loss betore in my fol
# l thine soms, And sins nelding on thee,
# For an eyelass potrinst, And sins on hel
#  marst I froug’s erdonce in luke chence
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.3353
# Epoch 97/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3045
# ---- Generating text after Epoch: 96
# ---- Generating with seed: "is gains? O him she stores, to show what"
#
#                  96
# is gains? O him she stores, to show what
#  to seefll in my stalting make and colt?
#  For do then me arturing in plook, nerpe
# st’s hised of hy sobl bllamone, For bron
# g deathie, And gevere or se). away What
# Iak no materking on welle, And me her ve
# rbe, Which it ost blease, or call then w
# hou ar un all, But when wifme stall ploo
# king night.   33  When thous is in cheng
# e and ome, and amb deat reised ous with
# bear that what it doon, That it roth fro
# m your nere, And ging ey like her doat,
# thou art but fiifle thue cortame to love
#  thee bard whore all think now home day,
#
# 18918/18918 [==============================] - 38s 2ms/sample - loss: 0.3046
# Epoch 98/100
# 18880/18918 [============================>.] - ETA: 0s - loss: 0.3193
# ---- Generating text after Epoch: 97
# ---- Generating with seed: "h hath not figured to thee my true spiri"
#
#                  97
# h hath not figured to thee my true spiri
# t, whow’s nother tret, houds thy werive
# at me fromerr will me his marsere to loo
# d, And thy bear.   49  Then the wins tho
# u fortw, For time crook of loakine since
#  makion I sme. Or’ thre, All otsurine of
#  my course wrich thy bet-love’s speit ou
# t resime, Orouth the come: Incow me, and
#  made, Than sen allouste, not to me bori
# ve of love as finely no were.   l8  Blas
# s drou, in her thou he ow, That if it no
# t bosimen.  s f1rsif’’ that muring faigr
# e he ot me injugied, And fearth then the
#  could.   4  Ij mort, Leat bet at anoers
#
# 18918/18918 [==============================] - 37s 2ms/sample - loss: 0.3196
# Epoch 99/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.2756
# ---- Generating text after Epoch: 98
# ---- Generating with seed: " beauty herself is black, And all they f"
#
#                  98
#  beauty herself is black, And all they f
# air friend and more I moth rame diews. M
# uken was of evenotest in pearth thenethu
# ry pow, than sumpare by gute a dyous ast
# ingt, The fourds To stend. Whic thurif’s
#  fint, and thers all the ploaking. Thee
# fror frimel of hears, Tyes part, thangou
# ght my wett dost live to seen, Sulth tru
# t shall many duce live the detend scays.
#    32  O arous an in leartat of will If
# as on ercuill take will his breatyll: it
#  chest that he se batian bar in thee inw
# ered dut eaves, ben mose, leaves look ye
# l, mure be thend I knoulds.  whet face a
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.2756
# Epoch 100/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.2957
# ---- Generating text after Epoch: 99
# ---- Generating with seed: "ring ill. Presume not on thy heart when "
#
#                  99
# ring ill. Presume not on thy heart when
# they face acqueat of tont, where blat me
# r-govely, Not in thy speet That is not b
# ut repaice.   140  Tin oun be sweet vore
#  doth That I not hour stall materp my ca
# nninst, And douth their, Or thm the swat
#  all, And the beture, Will ow leauty me
# to thy pparning wofth purt mide bothinge
# , And give’s parrence of my wolt arcuite
# d creep-cleal yet me worts The desens it
#  repay.   47  Thye tha pure s un the day
#  no parter froomer in look, And you hers
#  as the caintand, And worte be bost prio
# n than that stind, The bet othourst cill
#
# 18918/18918 [==============================] - 36s 2ms/sample - loss: 0.2958

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
